# %%
import pandas as pandas
import numpy as np
# Out:
# Les cellules en cours d’exécution avec Python 3.12.3 nécessitent le package ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Créer un environnement Python</a> avec les packages requis.
#
# Ou installez « ipykernel » en utilisant la commande : « /usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall »
